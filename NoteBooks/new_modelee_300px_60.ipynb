# %% [markdown]
# #dependencies

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
import numpy as np 
import pandas as pd
import os
import shutil

import cv2
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# %%
print('dn')
# Out:
# dn

# %%
tf.__version__
# Out:
# '2.5.0'

# %% [markdown]
# #import data

# %%
df = pd.read_csv('train.csv')
sub = pd.read_csv('sample_submission.csv')
GCS_DS_PATH = 'gs://kds-c0e7d059f0c458599814e594a1cf6bcd0d5213a258c8a18944ad84ba'
AUTO = tf.data.experimental.AUTOTUNE

# %%
df.head()
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0

# %%
df.shape
# Out:
# (1821, 5)

# %%
data=df[df['multiple_diseases']!=1]

# %%
data.shape
# Out:
# (1730, 5)

# %%
data.head()
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0
# 5  Train_5        1                  0     0     0

# %%
data.drop(columns='multiple_diseases', inplace=True)
# Out:
# C:\Users\zakaria\anaconda3\lib\site-packages\pandas\core\frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data.shape
# Out:
# (1730, 4)

# %%
IMG_SIZE = 300

def seed_everything(seed=0):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

seed = 2048
seed_everything(seed)
print("REPLICAS: ", 8)



#paths

data_paths = data.image_id.apply(lambda x: 'images/' + x + '.jpg').values


#labels

data_labels = data.loc[:, ['healthy','scab','rust']].values

#split train data to train and valisation data 
train_paths, test_paths, train_labels, test_labels =train_test_split(data_paths, data_labels, test_size=0.2, random_state=seed)

SPLIT_VALIDATION =True
if SPLIT_VALIDATION:
    train_paths, valid_paths, train_labels, valid_labels =train_test_split(train_paths, train_labels, test_size=0.2, random_state=seed)
print(len(train_paths))
print(len(test_paths))
print(len(valid_paths))

def decode_image(filename, label=None, IMG_SIZE=(IMG_SIZE, IMG_SIZE)):
    bits = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(bits, channels=3)
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.resize(image, IMG_SIZE)
    
    if label is None:
        return image
    else:
        return image, label


def data_augment(image, label=None):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    
    if label is None:
        return image
    else:
        return image, label
# Out:
# REPLICAS:  8
# 1107
# 346
# 277

# %% [markdown]
# #building the dataset(train, test, validation)

# %%
BATCH_SIZE = 8

train_dataset = (
tf.data.Dataset
    .from_tensor_slices((train_paths, train_labels))
    .map(decode_image, num_parallel_calls=AUTO)
    .cache()
    .map(data_augment, num_parallel_calls=AUTO)
    .repeat()
    .shuffle(512)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

train_dataset_1 = (
    tf.data.Dataset
    .from_tensor_slices((train_paths, train_labels))
    .map(decode_image, num_parallel_calls=AUTO)
    .cache()
    .map(data_augment, num_parallel_calls=AUTO)
    .repeat()
    .shuffle(512)
    .batch(8)
    .prefetch(AUTO)
)


valid_dataset = (
    tf.data.Dataset
    .from_tensor_slices((valid_paths, valid_labels))
    .map(decode_image, num_parallel_calls=AUTO)
    .batch(8)
    .cache()
    .prefetch(AUTO)
)


test_dataset = (
    tf.data.Dataset
    .from_tensor_slices((test_paths, test_labels))
    .map(decode_image, num_parallel_calls=AUTO)
    .map(data_augment, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
)

# %% [markdown]
# #hyperparametres

# %%
LR_START = 0.00001
LR_MAX = 0.00005 
LR_MIN = 0.00001
LR_RAMPUP_EPOCHS = 4
LR_SUSTAIN_EPOCHS = 6
LR_EXP_DECAY = .8

def lrfn(epoch):
    if epoch < LR_RAMPUP_EPOCHS:
        lr = (LR_MAX - LR_START) / LR_RAMPUP_EPOCHS * epoch + LR_START
    elif epoch < LR_RAMPUP_EPOCHS + LR_SUSTAIN_EPOCHS:
        lr = LR_MAX
    else:
        lr = (LR_MAX - LR_MIN) * LR_EXP_DECAY**(epoch - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS) + LR_MIN
    return lr
    
lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

# %% [markdown]
# #data visualisation

# %%
from matplotlib import pyplot as plt

img = plt.imread('images/Train_7.jpg')
print(img.shape)
plt.imshow(img)
# Out:
# (1365, 2048, 3)

# %%
print(data.sum())
pcts = data.mean()
pcts.plot(kind = 'bar')
# Out:
# image_id    Train_0Train_2Train_3Train_4Train_5Train_7Trai...
# healthy                                                   516
# rust                                                      622
# scab                                                      592
# dtype: object
# <ipython-input-17-089b829e98a5>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pcts = data.mean()
# <AxesSubplot:>

# %%
pcts.plot(kind = 'pie',autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
import h5py
h5py.__version__
# Out:
# '3.1.0'

# %% [markdown]
# #building our model

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow import keras
IMG_SIZE=300

from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D,Dense,MaxPool2D,Activation,Dropout,Flatten
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.models import Model
import tensorflow.keras
from tensorflow.keras import optimizers

model = Sequential()

model.add(Conv2D(32, kernel_size=(5,5),activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)))
model.add(BatchNormalization(axis=-1,center=True,scale=False))
model.add(Conv2D(128, kernel_size=(5,5),activation='relu'))
model.add(BatchNormalization(axis=-1,center=True,scale=False))
model.add(MaxPooling2D(pool_size=(2,2), padding='SAME'))
model.add(Dropout(.25))

model.add(Conv2D(32, kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization(axis=-1,center=True,scale=False))
model.add(Conv2D(128, kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization(axis=-1,center=True,scale=False))
model.add(MaxPooling2D(pool_size=(2,2), padding='SAME'))
model.add(Dropout(.25))


model.add(Conv2D(128, kernel_size=(5,5),activation='relu'))
model.add(BatchNormalization(axis=-1,center=True,scale=False))
model.add(Conv2D(512, kernel_size=(5,5),activation='relu'))
model.add(BatchNormalization(axis=-1,center=True,scale=False))
model.add(MaxPooling2D(pool_size=(2,2), padding='SAME'))
model.add(Dropout(.25))

model.add(Conv2D(128, kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization(axis=-1,center=True,scale=False))
model.add(Conv2D(512, kernel_size=(3,3),activation='relu'))
model.add(BatchNormalization(axis=-1,center=True,scale=False))
model.add(MaxPooling2D(pool_size=(2,2), padding='SAME'))
model.add(Dropout(.25))

model.add(Flatten())
model.add(Dense(300,activation='relu'))
model.add(BatchNormalization(axis=-1,center=True,scale=False))
model.add(Dropout(.25))
model.add(Dense(200,activation='relu'))
model.add(BatchNormalization(axis=-1,center=True,scale=False))
model.add(Dropout(.25))
model.add(Dense(100,activation='relu'))
model.add(BatchNormalization(axis=-1,center=True,scale=False))
model.add(Dropout(.25))
model.add(Dense(3,activation='softmax'))

model.summary()



model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy']
              )
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 296, 296, 32)      2432
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 296, 296, 32)      96
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 292, 292, 128)     102528
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 292, 292, 128)     384
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 146, 146, 128)     0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 146, 146, 128)     0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 144, 144, 32)      36896
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 144, 144, 32)      96
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 142, 142, 128)     36992
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 142, 142, 128)     384
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 71, 71, 128)       0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 71, 71, 128)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 67, 67, 128)       409728
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 67, 67, 128)       384
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 63, 63, 512)       1638912
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 63, 63, 512)       1536
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 32, 32, 512)       0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 32, 32, 512)       0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 30, 30, 128)       589952
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 30, 30, 128)       384
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 28, 28, 512)       590336
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 28, 28, 512)       1536
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 14, 14, 512)       0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 14, 14, 512)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_8 (Dense)              (None, 300)               30105900
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 300)               900
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 300)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 200)               60200
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 200)               600
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 100)               20100
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 100)               300
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 303
# =================================================================
# Total params: 33,600,879
# Trainable params: 33,596,479
# Non-trainable params: 4,400
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 296, 296, 32)      2432
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 296, 296, 32)      96
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 292, 292, 128)     102528
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 292, 292, 128)     384
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 146, 146, 128)     0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 146, 146, 128)     0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 144, 144, 32)      36896
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 144, 144, 32)      96
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 142, 142, 128)     36992
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 142, 142, 128)     384
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 71, 71, 128)       0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 71, 71, 128)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 67, 67, 128)       409728
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 67, 67, 128)       384
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 63, 63, 512)       1638912
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 63, 63, 512)       1536
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 32, 32, 512)       0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 32, 32, 512)       0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 30, 30, 128)       589952
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 30, 30, 128)       384
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 28, 28, 512)       590336
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 28, 28, 512)       1536
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 14, 14, 512)       0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 14, 14, 512)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_8 (Dense)              (None, 300)               30105900
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 300)               900
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 300)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 200)               60200
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 200)               600
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 100)               20100
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 100)               300
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 303
# =================================================================
# Total params: 33,600,879
# Trainable params: 33,596,479
# Non-trainable params: 4,400
# _________________________________________________________________

# %%
history=model.fit(
    train_dataset,
    steps_per_epoch=train_labels.shape[0] // BATCH_SIZE,
    epochs=60,
    validation_data=valid_dataset)
# Out:
# Epoch 1/60
# 138/138 [==============================] - 72s 386ms/step - loss: 1.5368 - accuracy: 0.3668 - val_loss: 1.1844 - val_accuracy: 0.3285
# Epoch 2/60
# 138/138 [==============================] - 47s 339ms/step - loss: 1.4187 - accuracy: 0.3623 - val_loss: 3.6000 - val_accuracy: 0.3466
# Epoch 3/60
# 138/138 [==============================] - 47s 340ms/step - loss: 1.2822 - accuracy: 0.3668 - val_loss: 5.0534 - val_accuracy: 0.3646
# Epoch 4/60
# 138/138 [==============================] - 48s 346ms/step - loss: 1.2184 - accuracy: 0.3877 - val_loss: 1.9312 - val_accuracy: 0.3791
# Epoch 5/60
# 138/138 [==============================] - 48s 348ms/step - loss: 1.1661 - accuracy: 0.3976 - val_loss: 1.9733 - val_accuracy: 0.4224
# Epoch 6/60
# 138/138 [==============================] - 48s 348ms/step - loss: 1.1684 - accuracy: 0.3886 - val_loss: 1.5142 - val_accuracy: 0.3285
# Epoch 7/60
# 138/138 [==============================] - 48s 349ms/step - loss: 1.1381 - accuracy: 0.3940 - val_loss: 1.2738 - val_accuracy: 0.4079
# Epoch 8/60
# 138/138 [==============================] - 48s 349ms/step - loss: 1.1257 - accuracy: 0.3967 - val_loss: 1.2398 - val_accuracy: 0.3718
# Epoch 9/60
# 138/138 [==============================] - 48s 349ms/step - loss: 1.0944 - accuracy: 0.4303 - val_loss: 1.0840 - val_accuracy: 0.3935
# Epoch 10/60
# 138/138 [==============================] - 48s 349ms/step - loss: 1.0678 - accuracy: 0.4266 - val_loss: 1.1709 - val_accuracy: 0.3863
# Epoch 11/60
# 138/138 [==============================] - 48s 349ms/step - loss: 1.0451 - accuracy: 0.4429 - val_loss: 1.3885 - val_accuracy: 0.3646
# Epoch 12/60
# 138/138 [==============================] - 48s 348ms/step - loss: 1.0621 - accuracy: 0.4574 - val_loss: 1.0120 - val_accuracy: 0.4549
# Epoch 13/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.9830 - accuracy: 0.5136 - val_loss: 0.9957 - val_accuracy: 0.4982
# Epoch 14/60
# 138/138 [==============================] - 48s 350ms/step - loss: 0.9921 - accuracy: 0.4955 - val_loss: 1.0368 - val_accuracy: 0.4404
# Epoch 15/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.9064 - accuracy: 0.5534 - val_loss: 1.2224 - val_accuracy: 0.3971
# Epoch 16/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.9030 - accuracy: 0.5453 - val_loss: 1.4434 - val_accuracy: 0.3791
# Epoch 17/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.8993 - accuracy: 0.5543 - val_loss: 0.8887 - val_accuracy: 0.5090
# Epoch 18/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.7959 - accuracy: 0.6159 - val_loss: 1.0035 - val_accuracy: 0.5090
# Epoch 19/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.8433 - accuracy: 0.5933 - val_loss: 0.7840 - val_accuracy: 0.6137
# Epoch 20/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.7767 - accuracy: 0.6168 - val_loss: 0.7241 - val_accuracy: 0.6787
# Epoch 21/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.7438 - accuracy: 0.6495 - val_loss: 0.6630 - val_accuracy: 0.7256
# Epoch 22/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.7218 - accuracy: 0.6712 - val_loss: 0.6833 - val_accuracy: 0.6931
# Epoch 23/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.6983 - accuracy: 0.7029 - val_loss: 0.7373 - val_accuracy: 0.6606
# Epoch 24/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.6305 - accuracy: 0.7228 - val_loss: 1.6381 - val_accuracy: 0.4765
# Epoch 25/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.4971 - accuracy: 0.7953 - val_loss: 0.5840 - val_accuracy: 0.7978
# Epoch 26/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.4891 - accuracy: 0.8089 - val_loss: 0.4341 - val_accuracy: 0.8267
# Epoch 27/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.4374 - accuracy: 0.8578 - val_loss: 5.2343 - val_accuracy: 0.3682
# Epoch 28/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.4036 - accuracy: 0.8569 - val_loss: 0.4702 - val_accuracy: 0.8231
# Epoch 29/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.3461 - accuracy: 0.8913 - val_loss: 1.2090 - val_accuracy: 0.5921
# Epoch 30/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.4004 - accuracy: 0.8687 - val_loss: 0.4062 - val_accuracy: 0.8484
# Epoch 31/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.3873 - accuracy: 0.8696 - val_loss: 0.2807 - val_accuracy: 0.9134
# Epoch 32/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.3473 - accuracy: 0.8705 - val_loss: 0.8521 - val_accuracy: 0.6931
# Epoch 33/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.3732 - accuracy: 0.8659 - val_loss: 0.6941 - val_accuracy: 0.7437
# Epoch 34/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.3304 - accuracy: 0.8967 - val_loss: 0.5186 - val_accuracy: 0.8412
# Epoch 35/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.3006 - accuracy: 0.8931 - val_loss: 0.1902 - val_accuracy: 0.9350
# Epoch 36/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.2905 - accuracy: 0.8976 - val_loss: 0.2089 - val_accuracy: 0.9314
# Epoch 37/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.3048 - accuracy: 0.8958 - val_loss: 0.4073 - val_accuracy: 0.8592
# Epoch 38/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.2883 - accuracy: 0.9004 - val_loss: 0.3944 - val_accuracy: 0.8448
# Epoch 39/60
# 138/138 [==============================] - 48s 347ms/step - loss: 0.2685 - accuracy: 0.9076 - val_loss: 0.6664 - val_accuracy: 0.7906
# Epoch 40/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.2591 - accuracy: 0.9203 - val_loss: 0.5981 - val_accuracy: 0.8520
# Epoch 41/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.2931 - accuracy: 0.9022 - val_loss: 0.4204 - val_accuracy: 0.8592
# Epoch 42/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.2488 - accuracy: 0.9248 - val_loss: 0.2254 - val_accuracy: 0.9350
# Epoch 43/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.2233 - accuracy: 0.9203 - val_loss: 0.3711 - val_accuracy: 0.8845
# Epoch 44/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.2040 - accuracy: 0.9330 - val_loss: 0.1431 - val_accuracy: 0.9495
# Epoch 45/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.2278 - accuracy: 0.9230 - val_loss: 0.2457 - val_accuracy: 0.9242
# Epoch 46/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.2375 - accuracy: 0.9275 - val_loss: 0.3109 - val_accuracy: 0.8989
# Epoch 47/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.2232 - accuracy: 0.9330 - val_loss: 0.1795 - val_accuracy: 0.9531
# Epoch 48/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.2292 - accuracy: 0.9239 - val_loss: 0.3989 - val_accuracy: 0.8773
# Epoch 49/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.2317 - accuracy: 0.9284 - val_loss: 0.4456 - val_accuracy: 0.8484
# Epoch 50/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.2329 - accuracy: 0.9275 - val_loss: 0.2011 - val_accuracy: 0.9097
# Epoch 51/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.1997 - accuracy: 0.9384 - val_loss: 0.1486 - val_accuracy: 0.9531
# Epoch 52/60
# 138/138 [==============================] - 48s 348ms/step - loss: 0.1842 - accuracy: 0.9366 - val_loss: 0.2945 - val_accuracy: 0.9170
# Epoch 53/60
# 138/138 [==============================] - 48s 351ms/step - loss: 0.2406 - accuracy: 0.9275 - val_loss: 0.2061 - val_accuracy: 0.9495
# Epoch 54/60
# 138/138 [==============================] - 48s 351ms/step - loss: 0.2565 - accuracy: 0.9194 - val_loss: 0.1616 - val_accuracy: 0.9386
# Epoch 55/60
# 138/138 [==============================] - 48s 350ms/step - loss: 0.1766 - accuracy: 0.9411 - val_loss: 0.1540 - val_accuracy: 0.9531
# Epoch 56/60
# 138/138 [==============================] - 49s 352ms/step - loss: 0.1997 - accuracy: 0.9429 - val_loss: 0.1745 - val_accuracy: 0.9350
# Epoch 57/60
# 138/138 [==============================] - 48s 347ms/step - loss: 0.1684 - accuracy: 0.9447 - val_loss: 0.1614 - val_accuracy: 0.9495
# Epoch 58/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.2162 - accuracy: 0.9312 - val_loss: 0.2263 - val_accuracy: 0.9242
# Epoch 59/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.2373 - accuracy: 0.9176 - val_loss: 0.1726 - val_accuracy: 0.9603
# Epoch 60/60
# 138/138 [==============================] - 48s 349ms/step - loss: 0.1813 - accuracy: 0.9484 - val_loss: 0.1771 - val_accuracy: 0.9422

# %% [markdown]
# #show the loss and the accuracy

# %%
def display_training_curves(training, validation, title, subplot):
    if subplot%10==1: # set up the subplots on the first call
        plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
        #plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    #ax.set_ylim(0.28,1.05)
    ax.set_xlabel('epoch')
    ax.legend(['train', 'valid.'])

# %%
display_training_curves(history.history['accuracy'][1:], history.history['val_accuracy'][1:], 'accuracy', 211)
display_training_curves(history.history['loss'][1:], history.history['val_loss'][1:], 'loss', 212)

# %%
print("Evaluate on test data")
results = model.evaluate(test_dataset, batch_size=8)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 44/44 [==============================] - 12s 237ms/step - loss: 0.2080 - accuracy: 0.9335
# test loss, test acc: [0.20795570313930511, 0.9335260391235352]

# %%
import pickle
with open('training_log/new_modelss_300px_60_kaggle1.pkl', 'wb') as output:
        pickle.dump(history.history, output)

# %%
model.save('new_modelss')
# Out:
# INFO:tensorflow:Assets written to: new_modelss\assets
