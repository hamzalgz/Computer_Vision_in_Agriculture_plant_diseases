# %% [markdown]
# #dependencies

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
import numpy as np 
import pandas as pd
import os
import shutil

import cv2
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# %%
print('dn')
# Out:
# dn

# %%
tf.__version__
# Out:
# '2.5.0'

# %% [markdown]
# #import data

# %%
df = pd.read_csv('train.csv')
sub = pd.read_csv('sample_submission.csv')
GCS_DS_PATH = 'gs://kds-c0e7d059f0c458599814e594a1cf6bcd0d5213a258c8a18944ad84ba'
AUTO = tf.data.experimental.AUTOTUNE

# %%
df.head()
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0

# %%
df.shape
# Out:
# (1821, 5)

# %%
data=df[df['multiple_diseases']!=1]

# %%
data.shape
# Out:
# (1730, 5)

# %%
data.head()
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0
# 5  Train_5        1                  0     0     0

# %%
data.drop(columns='multiple_diseases', inplace=True)
# Out:
# C:\Users\zakaria\anaconda3\lib\site-packages\pandas\core\frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data.shape
# Out:
# (1730, 4)

# %%
IMG_SIZE = 300

def seed_everything(seed=0):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

seed = 2048
seed_everything(seed)
print("REPLICAS: ", 8)



#paths

data_paths = data.image_id.apply(lambda x: 'images/' + x + '.jpg').values


#labels

data_labels = data.loc[:, ['healthy','scab','rust']].values

#split train data to train and valisation data 
train_paths, test_paths, train_labels, test_labels =train_test_split(data_paths, data_labels, test_size=0.2, random_state=seed)

SPLIT_VALIDATION =True
if SPLIT_VALIDATION:
    train_paths, valid_paths, train_labels, valid_labels =train_test_split(train_paths, train_labels, test_size=0.2, random_state=seed)
print(len(train_paths))
print(len(test_paths))
print(len(valid_paths))

def decode_image(filename, label=None, IMG_SIZE=(IMG_SIZE, IMG_SIZE)):
    bits = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(bits, channels=3)
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.resize(image, IMG_SIZE)
    
    if label is None:
        return image
    else:
        return image, label


def data_augment(image, label=None):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    
    if label is None:
        return image
    else:
        return image, label
# Out:
# REPLICAS:  8
# 1107
# 346
# 277

# %% [markdown]
# #building the dataset(train, test, validation)

# %%
BATCH_SIZE = 8

train_dataset = (
tf.data.Dataset
    .from_tensor_slices((train_paths, train_labels))
    .map(decode_image, num_parallel_calls=AUTO)
    .cache()
    .map(data_augment, num_parallel_calls=AUTO)
    .repeat()
    .shuffle(512)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

train_dataset_1 = (
    tf.data.Dataset
    .from_tensor_slices((train_paths, train_labels))
    .map(decode_image, num_parallel_calls=AUTO)
    .cache()
    .map(data_augment, num_parallel_calls=AUTO)
    .repeat()
    .shuffle(512)
    .batch(8)
    .prefetch(AUTO)
)


valid_dataset = (
    tf.data.Dataset
    .from_tensor_slices((valid_paths, valid_labels))
    .map(decode_image, num_parallel_calls=AUTO)
    .batch(8)
    .cache()
    .prefetch(AUTO)
)


test_dataset = (
    tf.data.Dataset
    .from_tensor_slices((test_paths, test_labels))
    .map(decode_image, num_parallel_calls=AUTO)
    .map(data_augment, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
)

# %% [markdown]
# #hyperparametres

# %%
LR_START = 0.00001
LR_MAX = 0.00005 
LR_MIN = 0.00001
LR_RAMPUP_EPOCHS = 4
LR_SUSTAIN_EPOCHS = 6
LR_EXP_DECAY = .8

def lrfn(epoch):
    if epoch < LR_RAMPUP_EPOCHS:
        lr = (LR_MAX - LR_START) / LR_RAMPUP_EPOCHS * epoch + LR_START
    elif epoch < LR_RAMPUP_EPOCHS + LR_SUSTAIN_EPOCHS:
        lr = LR_MAX
    else:
        lr = (LR_MAX - LR_MIN) * LR_EXP_DECAY**(epoch - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS) + LR_MIN
    return lr
    
lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

# %% [markdown]
# #data visualisation

# %%
from matplotlib import pyplot as plt

img = plt.imread('images/Train_7.jpg')
print(img.shape)
plt.imshow(img)
# Out:
# (1365, 2048, 3)

# %%
print(data.sum())
pcts = data.mean()
pcts.plot(kind = 'bar')
# Out:
# image_id    Train_0Train_2Train_3Train_4Train_5Train_7Trai...
# healthy                                                   516
# rust                                                      622
# scab                                                      592
# dtype: object
# <ipython-input-47-089b829e98a5>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pcts = data.mean()
# <AxesSubplot:>

# %%
pcts.plot(kind = 'pie',autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
import h5py
h5py.__version__
# Out:
# '3.1.0'

# %% [markdown]
# #building our model

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow import keras
IMG_SIZE=300

base_model = tf.keras.applications.MobileNetV2(input_shape=(IMG_SIZE,IMG_SIZE,3),
                                               include_top=False,
                                               weights='imagenet')
x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(3, activation='softmax')(x)
model =  keras.Model(inputs = base_model.input,outputs=x)

model.compile( optimizer= 'adam',loss="categorical_crossentropy", metrics=["accuracy"])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 150, 150, 32) 864         input_3[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 150, 150, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 150, 150, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 150, 150, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 150, 150, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 150, 150, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 150, 150, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 150, 150, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 150, 150, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 150, 150, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 150, 150, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 151, 151, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 75, 75, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 75, 75, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 75, 75, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 75, 75, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 75, 75, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 75, 75, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 75, 75, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 75, 75, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 75, 75, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 75, 75, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 75, 75, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 75, 75, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 75, 75, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 75, 75, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 75, 75, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 75, 75, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 75, 75, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 77, 77, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 38, 38, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 38, 38, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 38, 38, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 38, 38, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 38, 38, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 38, 38, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 38, 38, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 38, 38, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 38, 38, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 38, 38, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 38, 38, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 38, 38, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 38, 38, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 38, 38, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 38, 38, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 38, 38, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 38, 38, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 38, 38, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 38, 38, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 38, 38, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 38, 38, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 38, 38, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 38, 38, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 38, 38, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 38, 38, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 38, 38, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 39, 39, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 19, 19, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 19, 19, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 19, 19, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 19, 19, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 19, 19, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 19, 19, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 19, 19, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 19, 19, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 19, 19, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 19, 19, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 19, 19, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 19, 19, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 19, 19, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 19, 19, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 19, 19, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 19, 19, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 19, 19, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 19, 19, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 19, 19, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 19, 19, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 19, 19, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 19, 19, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 19, 19, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 19, 19, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 19, 19, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 19, 19, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 19, 19, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 19, 19, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 19, 19, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 19, 19, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 19, 19, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 19, 19, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 19, 19, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 19, 19, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 19, 19, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 19, 19, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 19, 19, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 19, 19, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 19, 19, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 19, 19, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 19, 19, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 19, 19, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 19, 19, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 19, 19, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 19, 19, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 19, 19, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 19, 19, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 19, 19, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 19, 19, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 19, 19, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 19, 19, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 19, 19, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 19, 19, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 19, 19, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 19, 19, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 19, 19, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 19, 19, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 19, 19, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 19, 19, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 19, 19, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 19, 19, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 21, 21, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 10, 10, 576)  5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 10, 10, 576)  2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 10, 10, 576)  0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 10, 10, 160)  92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 10, 10, 160)  640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 10, 10, 960)  153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 10, 10, 960)  3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 10, 10, 960)  0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 10, 10, 960)  8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 10, 10, 960)  3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 10, 10, 960)  0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 10, 10, 160)  153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 10, 10, 160)  640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 10, 10, 160)  0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 10, 10, 960)  153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 10, 10, 960)  3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 10, 10, 960)  0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 10, 10, 960)  8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 10, 10, 960)  3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 10, 10, 960)  0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 10, 10, 160)  153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 10, 10, 160)  640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 10, 10, 160)  0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 10, 10, 960)  153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 10, 10, 960)  3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 10, 10, 960)  0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 10, 10, 960)  8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 10, 10, 960)  3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 10, 10, 960)  0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 10, 10, 320)  307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 10, 10, 320)  1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 10, 10, 1280) 409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 10, 10, 1280) 5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 10, 10, 1280) 0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 1280)         0           out_relu[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            3843        global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 2,261,827
# Trainable params: 2,227,715
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
history=model.fit(
    train_dataset,
    steps_per_epoch=train_labels.shape[0] // BATCH_SIZE,
    epochs=80,
    validation_data=valid_dataset)
# Out:
# Epoch 1/80
# 138/138 [==============================] - 59s 268ms/step - loss: 0.5142 - accuracy: 0.8143 - val_loss: 6.5559 - val_accuracy: 0.4079
# Epoch 2/80
# 138/138 [==============================] - 21s 154ms/step - loss: 0.3131 - accuracy: 0.8958 - val_loss: 26.2470 - val_accuracy: 0.3682
# Epoch 3/80
# 138/138 [==============================] - 21s 155ms/step - loss: 0.2392 - accuracy: 0.9257 - val_loss: 6.8323 - val_accuracy: 0.3682
# Epoch 4/80
# 138/138 [==============================] - 21s 154ms/step - loss: 0.1875 - accuracy: 0.9402 - val_loss: 21.8689 - val_accuracy: 0.3682
# Epoch 5/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.1876 - accuracy: 0.9402 - val_loss: 23.6391 - val_accuracy: 0.3682
# Epoch 6/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.1625 - accuracy: 0.9538 - val_loss: 16.2018 - val_accuracy: 0.3682
# Epoch 7/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.1578 - accuracy: 0.9502 - val_loss: 25.0840 - val_accuracy: 0.3682
# Epoch 8/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.1357 - accuracy: 0.9520 - val_loss: 17.6375 - val_accuracy: 0.3863
# Epoch 9/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.1194 - accuracy: 0.9620 - val_loss: 1.2178 - val_accuracy: 0.6606
# Epoch 10/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.1535 - accuracy: 0.9556 - val_loss: 15.2315 - val_accuracy: 0.3682
# Epoch 11/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.1172 - accuracy: 0.9601 - val_loss: 21.8572 - val_accuracy: 0.3682
# Epoch 12/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.1161 - accuracy: 0.9574 - val_loss: 14.8446 - val_accuracy: 0.3682
# Epoch 13/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.0954 - accuracy: 0.9674 - val_loss: 5.2706 - val_accuracy: 0.4043
# Epoch 14/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.0531 - accuracy: 0.9801 - val_loss: 9.9671 - val_accuracy: 0.3827
# Epoch 15/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0717 - accuracy: 0.9774 - val_loss: 5.4413 - val_accuracy: 0.4585
# Epoch 16/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0905 - accuracy: 0.9719 - val_loss: 6.6354 - val_accuracy: 0.4693
# Epoch 17/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.1111 - accuracy: 0.9683 - val_loss: 8.4634 - val_accuracy: 0.4368
# Epoch 18/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.0654 - accuracy: 0.9774 - val_loss: 7.5709 - val_accuracy: 0.4079
# Epoch 19/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0661 - accuracy: 0.9792 - val_loss: 0.8713 - val_accuracy: 0.8664
# Epoch 20/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.1337 - accuracy: 0.9647 - val_loss: 0.9367 - val_accuracy: 0.8123
# Epoch 21/80
# 138/138 [==============================] - 21s 154ms/step - loss: 0.1209 - accuracy: 0.9601 - val_loss: 2.9953 - val_accuracy: 0.4188
# Epoch 22/80
# 138/138 [==============================] - 21s 155ms/step - loss: 0.0771 - accuracy: 0.9719 - val_loss: 8.6415 - val_accuracy: 0.4007
# Epoch 23/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.0472 - accuracy: 0.9819 - val_loss: 5.6431 - val_accuracy: 0.5560
# Epoch 24/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.1053 - accuracy: 0.9656 - val_loss: 6.4858 - val_accuracy: 0.3321
# Epoch 25/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0698 - accuracy: 0.9819 - val_loss: 8.6850 - val_accuracy: 0.4332
# Epoch 26/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0376 - accuracy: 0.9900 - val_loss: 9.7725 - val_accuracy: 0.3791
# Epoch 27/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0904 - accuracy: 0.9728 - val_loss: 5.8540 - val_accuracy: 0.5090
# Epoch 28/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.0953 - accuracy: 0.9755 - val_loss: 5.8266 - val_accuracy: 0.6318
# Epoch 29/80
# 138/138 [==============================] - 22s 156ms/step - loss: 0.0673 - accuracy: 0.9792 - val_loss: 1.8581 - val_accuracy: 0.7040
# Epoch 30/80
# 138/138 [==============================] - 21s 154ms/step - loss: 0.0352 - accuracy: 0.9882 - val_loss: 0.8884 - val_accuracy: 0.8195
# Epoch 31/80
# 138/138 [==============================] - 21s 155ms/step - loss: 0.0574 - accuracy: 0.9837 - val_loss: 0.5233 - val_accuracy: 0.8664
# Epoch 32/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.0535 - accuracy: 0.9882 - val_loss: 0.4105 - val_accuracy: 0.9206
# Epoch 33/80
# 138/138 [==============================] - 21s 156ms/step - loss: 0.0757 - accuracy: 0.9774 - val_loss: 0.4783 - val_accuracy: 0.8953
# Epoch 34/80
# 138/138 [==============================] - 21s 156ms/step - loss: 0.0169 - accuracy: 0.9928 - val_loss: 0.5989 - val_accuracy: 0.8845
# Epoch 35/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.0609 - accuracy: 0.9819 - val_loss: 0.8791 - val_accuracy: 0.8231
# Epoch 36/80
# 138/138 [==============================] - 21s 154ms/step - loss: 0.0477 - accuracy: 0.9882 - val_loss: 1.2555 - val_accuracy: 0.7762
# Epoch 37/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0700 - accuracy: 0.9774 - val_loss: 0.5870 - val_accuracy: 0.8267
# Epoch 38/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.0555 - accuracy: 0.9837 - val_loss: 1.0991 - val_accuracy: 0.7942
# Epoch 39/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0414 - accuracy: 0.9837 - val_loss: 1.4551 - val_accuracy: 0.8231
# Epoch 40/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0289 - accuracy: 0.9918 - val_loss: 0.7205 - val_accuracy: 0.8773
# Epoch 41/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0359 - accuracy: 0.9891 - val_loss: 0.7264 - val_accuracy: 0.8845
# Epoch 42/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0307 - accuracy: 0.9909 - val_loss: 0.9562 - val_accuracy: 0.8195
# Epoch 43/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.0135 - accuracy: 0.9937 - val_loss: 2.2289 - val_accuracy: 0.7870
# Epoch 44/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0533 - accuracy: 0.9873 - val_loss: 0.6741 - val_accuracy: 0.8700
# Epoch 45/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0281 - accuracy: 0.9909 - val_loss: 0.2962 - val_accuracy: 0.9314
# Epoch 46/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.0151 - accuracy: 0.9964 - val_loss: 0.1637 - val_accuracy: 0.9711
# Epoch 47/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0378 - accuracy: 0.9873 - val_loss: 0.3524 - val_accuracy: 0.9422
# Epoch 48/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0415 - accuracy: 0.9864 - val_loss: 1.2313 - val_accuracy: 0.8087
# Epoch 49/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0323 - accuracy: 0.9873 - val_loss: 0.5479 - val_accuracy: 0.9242
# Epoch 50/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.0880 - accuracy: 0.9728 - val_loss: 0.9365 - val_accuracy: 0.8267
# Epoch 51/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.0816 - accuracy: 0.9819 - val_loss: 1.4703 - val_accuracy: 0.7112
# Epoch 52/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0454 - accuracy: 0.9891 - val_loss: 0.2519 - val_accuracy: 0.9350
# Epoch 53/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0480 - accuracy: 0.9855 - val_loss: 4.2084 - val_accuracy: 0.4946
# Epoch 54/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0301 - accuracy: 0.9909 - val_loss: 0.6143 - val_accuracy: 0.8303
# Epoch 55/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.0683 - accuracy: 0.9810 - val_loss: 1.2429 - val_accuracy: 0.7365
# Epoch 56/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0479 - accuracy: 0.9855 - val_loss: 3.8646 - val_accuracy: 0.5018
# Epoch 57/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.0230 - accuracy: 0.9937 - val_loss: 3.0021 - val_accuracy: 0.4874
# Epoch 58/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0207 - accuracy: 0.9928 - val_loss: 0.9820 - val_accuracy: 0.8592
# Epoch 59/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0249 - accuracy: 0.9918 - val_loss: 0.4400 - val_accuracy: 0.9206
# Epoch 60/80
# 138/138 [==============================] - 20s 147ms/step - loss: 0.0365 - accuracy: 0.9900 - val_loss: 0.5697 - val_accuracy: 0.8953
# Epoch 61/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0432 - accuracy: 0.9846 - val_loss: 0.9908 - val_accuracy: 0.8664
# Epoch 62/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.0216 - accuracy: 0.9955 - val_loss: 0.2897 - val_accuracy: 0.9495
# Epoch 63/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0149 - accuracy: 0.9964 - val_loss: 0.6116 - val_accuracy: 0.9061
# Epoch 64/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0410 - accuracy: 0.9882 - val_loss: 2.1199 - val_accuracy: 0.6137
# Epoch 65/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.0425 - accuracy: 0.9846 - val_loss: 1.3696 - val_accuracy: 0.7834
# Epoch 66/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.9768 - val_accuracy: 0.8159
# Epoch 67/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0058 - accuracy: 0.9973 - val_loss: 0.4148 - val_accuracy: 0.8953
# Epoch 68/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.0177 - accuracy: 0.9928 - val_loss: 0.8189 - val_accuracy: 0.8556
# Epoch 69/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0582 - accuracy: 0.9864 - val_loss: 1.2648 - val_accuracy: 0.7545
# Epoch 70/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0180 - accuracy: 0.9946 - val_loss: 0.3711 - val_accuracy: 0.9314
# Epoch 71/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.0219 - accuracy: 0.9891 - val_loss: 0.5445 - val_accuracy: 0.8953
# Epoch 72/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0080 - accuracy: 0.9982 - val_loss: 0.2763 - val_accuracy: 0.9314
# Epoch 73/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.0047 - accuracy: 0.9973 - val_loss: 0.2201 - val_accuracy: 0.9458
# Epoch 74/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1130 - val_accuracy: 0.9675
# Epoch 75/80
# 138/138 [==============================] - 21s 153ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.2045 - val_accuracy: 0.9603
# Epoch 76/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0873 - accuracy: 0.9819 - val_loss: 58.7450 - val_accuracy: 0.3682
# Epoch 77/80
# 138/138 [==============================] - 21s 151ms/step - loss: 0.0991 - accuracy: 0.9647 - val_loss: 3.2817 - val_accuracy: 0.4152
# Epoch 78/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0280 - accuracy: 0.9918 - val_loss: 10.7922 - val_accuracy: 0.4874
# Epoch 79/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0287 - accuracy: 0.9900 - val_loss: 1.3923 - val_accuracy: 0.8123
# Epoch 80/80
# 138/138 [==============================] - 21s 152ms/step - loss: 0.0180 - accuracy: 0.9918 - val_loss: 0.1885 - val_accuracy: 0.9783

# %% [markdown]
# #show the loss and the accuracy

# %%
def display_training_curves(training, validation, title, subplot):
    if subplot%10==1: # set up the subplots on the first call
        plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
        #plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    #ax.set_ylim(0.28,1.05)
    ax.set_xlabel('epoch')
    ax.legend(['train', 'valid.'])

# %%
display_training_curves(history.history['accuracy'][1:], history.history['val_accuracy'][1:], 'accuracy', 211)
display_training_curves(history.history['loss'][1:], history.history['val_loss'][1:], 'loss', 212)

# %%
print("Evaluate on test data")
results = model.evaluate(test_dataset, batch_size=8)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 44/44 [==============================] - 11s 230ms/step - loss: 0.1686 - accuracy: 0.9740
# test loss, test acc: [0.16857293248176575, 0.97398841381073]

# %%
import pickle
with open('training_log/MobileNetV2_300px_80_kaggle1.pkl', 'wb') as output:
        pickle.dump(history.history, output)

# %%
model.save('MobileNetV2_300px_80')
# Out:
# C:\Users\zakaria\anaconda3\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# INFO:tensorflow:Assets written to: MobileNetV2_300px_80\assets
